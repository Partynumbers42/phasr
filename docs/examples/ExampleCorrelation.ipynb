# %%
import phasr as phr

# %%
phr.__version__
# Out:
# '0.5.4.dev17+g192a65555'

# %%
import numpy as np
pi=np.pi
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reference Nucleus and Charge Radius

# %%
# Reference nucleus for Al27 (taken from Noel and Hoferichter, 2024)

# %%
ai_27Al = [0.03125, 0.05727, 0.02301, -0.01565, -0.0163, -0.0039, 0.0010] 
R_27Al = 8.0 
nuc_ref_27Al = phr.nucleus('Al27_bestfit_example',Z=13,A=27,ai=ai_27Al,R=R_27Al)

# %%
# According reference charge radius (also taken from Noel and Hoferichter, 2024)

# %%
r_ch_ref_27Al = 3.063 
dr_ch_ref_27Al = 0.031 
# 
r_ch_sq_ref_27Al = r_ch_ref_27Al**2 
dr_ch_sq_ref_27Al = 2*r_ch_ref_27Al*dr_ch_ref_27Al 
# 
r_ch_sq_ref_27Al, dr_ch_sq_ref_27Al
# Out:
# (9.381969000000002, 0.18990600000000002)

# %% [markdown]
# # Import Datasets

# %%
# We use as an example ab-initio calculations for 27Al using the IMSRG over a collection of different input chiral Hamiltonians (courtesy of Matthias Heinz)

# %%
AI_dict_27Al = phr.dirac_solvers.post_processing.correlation.prepare_results(Z=13,A=27,folder_path="./IMSRG_27Al/",name='Al27_ab_initio',r_cut=6)
# Out:
# Loaded datasets: ['1p82p0EM7p5', '1p82p0sim7p5', 'DN2LOGO', 'EM1p82p0', 'EM2p02p0', 'EM2p02p0PWA', 'EM2p22p0', 'N2LOsat', 'NIsample0090', 'NIsample0500', 'NIsample0606', 'NIsample0723', 'NIsample0750', 'NIsample0922', 'NIsample1141', 'NIsample1172', 'NIsample1173', 'NIsample1177', 'NIsample1469', 'NIsample1802', 'NIsample2007', 'NIsample2125', 'NIsample2245', 'NIsample2411', 'NIsample2460', 'NIsample3098', 'NIsample3105', 'NIsample3260', 'NIsample3319', 'NIsample3350', 'NIsample3448', 'NIsample3472', 'NIsample3480', 'NIsample3621', 'NIsample3895', 'NIsample4117']
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_1p82p0EM7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_1p82p0EM7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_1p82p0EM7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_1p82p0EM7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_1p82p0EM7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_1p82p0EM7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_1p82p0EM7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_1p82p0EM7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_1p82p0EM7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_1p82p0EM7p5_x=0.0-6-0.05.txt
# Radii (1p82p0EM7p5) are consistent up to a level of at least: 1.8e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_1p82p0sim7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_1p82p0sim7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_1p82p0sim7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_1p82p0sim7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_1p82p0sim7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_1p82p0sim7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_1p82p0sim7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_1p82p0sim7p5_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_1p82p0sim7p5_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_1p82p0sim7p5_x=0.0-6-0.05.txt
# Radii (1p82p0sim7p5) are consistent up to a level of at least: 1.6e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_DN2LOGO_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_DN2LOGO_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_DN2LOGO_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_DN2LOGO_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_DN2LOGO_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_DN2LOGO_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_DN2LOGO_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_DN2LOGO_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_DN2LOGO_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_DN2LOGO_x=0.0-6-0.05.txt
# Radii (DN2LOGO) are consistent up to a level of at least: 5.9e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_EM1p82p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_EM1p82p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_EM1p82p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_EM1p82p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_EM1p82p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_EM1p82p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_EM1p82p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_EM1p82p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_EM1p82p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_EM1p82p0_x=0.0-6-0.05.txt
# Radii (EM1p82p0) are consistent up to a level of at least: 7.4e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_EM2p02p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_EM2p02p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_EM2p02p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_EM2p02p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_EM2p02p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_EM2p02p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_EM2p02p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_EM2p02p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_EM2p02p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_EM2p02p0_x=0.0-6-0.05.txt
# Radii (EM2p02p0) are consistent up to a level of at least: 5.5e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_EM2p02p0PWA_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_EM2p02p0PWA_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_EM2p02p0PWA_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_EM2p02p0PWA_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_EM2p02p0PWA_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_EM2p02p0PWA_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_EM2p02p0PWA_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_EM2p02p0PWA_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_EM2p02p0PWA_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_EM2p02p0PWA_x=0.0-6-0.05.txt
# Radii (EM2p02p0PWA) are consistent up to a level of at least: 5.6e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_EM2p22p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_EM2p22p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_EM2p22p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_EM2p22p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_EM2p22p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_EM2p22p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_EM2p22p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_EM2p22p0_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_EM2p22p0_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_EM2p22p0_x=0.0-6-0.05.txt
# Radii (EM2p22p0) are consistent up to a level of at least: 3.3e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_N2LOsat_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_N2LOsat_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_N2LOsat_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_N2LOsat_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_N2LOsat_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_N2LOsat_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_N2LOsat_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_N2LOsat_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_N2LOsat_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_N2LOsat_x=0.0-6-0.05.txt
# Radii (N2LOsat) are consistent up to a level of at least: 7.4e-05
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample0090_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample0090_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample0090_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample0090_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample0090_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample0090_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample0090_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample0090_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample0090_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample0090_x=0.0-6-0.05.txt
# Radii (NIsample0090) are consistent up to a level of at least: 2.6e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample0500_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample0500_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample0500_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample0500_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample0500_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample0500_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample0500_x=0.0-6-0.05.txt
# Warning: x_crit adjusted to 5.903999999999968, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample0500_x=0.0-6.6000000000000005-0.05.txt
# Warning: x_crit adjusted to 6.299, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample0500_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample0500_x=0.0-6-0.05.txt
# Radii (NIsample0500) are consistent up to a level of at least: 3.0e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample0606_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample0606_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample0606_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample0606_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample0606_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample0606_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample0606_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample0606_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample0606_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample0606_x=0.0-6-0.05.txt
# Radii (NIsample0606) are consistent up to a level of at least: 3.9e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample0723_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample0723_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample0723_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample0723_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample0723_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample0723_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample0723_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample0723_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample0723_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample0723_x=0.0-6-0.05.txt
# Radii (NIsample0723) are consistent up to a level of at least: 2.9e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample0750_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample0750_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample0750_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample0750_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample0750_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample0750_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample0750_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample0750_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample0750_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample0750_x=0.0-6-0.05.txt
# Radii (NIsample0750) are consistent up to a level of at least: 3.3e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample0922_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample0922_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample0922_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample0922_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample0922_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample0922_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample0922_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample0922_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample0922_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample0922_x=0.0-6-0.05.txt
# Radii (NIsample0922) are consistent up to a level of at least: 3.1e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample1141_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample1141_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample1141_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample1141_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample1141_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample1141_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample1141_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample1141_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample1141_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample1141_x=0.0-6-0.05.txt
# Radii (NIsample1141) are consistent up to a level of at least: 3.9e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample1172_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample1172_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample1172_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample1172_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample1172_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample1172_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample1172_x=0.0-6-0.05.txt
# Warning: x_crit adjusted to 5.784999999999928, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample1172_x=0.0-6.6000000000000005-0.05.txt
# Warning: x_crit adjusted to 6.299, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample1172_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample1172_x=0.0-6-0.05.txt
# Radii (NIsample1172) are consistent up to a level of at least: 2.5e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample1173_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample1173_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample1173_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample1173_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample1173_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample1173_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample1173_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample1173_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample1173_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample1173_x=0.0-6-0.05.txt
# Radii (NIsample1173) are consistent up to a level of at least: 2.6e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample1177_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample1177_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample1177_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample1177_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample1177_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample1177_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample1177_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample1177_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample1177_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample1177_x=0.0-6-0.05.txt
# Radii (NIsample1177) are consistent up to a level of at least: 4.0e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample1469_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample1469_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample1469_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample1469_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample1469_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample1469_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample1469_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample1469_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample1469_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample1469_x=0.0-6-0.05.txt
# Radii (NIsample1469) are consistent up to a level of at least: 3.4e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample1802_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample1802_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample1802_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample1802_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample1802_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample1802_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample1802_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample1802_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample1802_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample1802_x=0.0-6-0.05.txt
# Radii (NIsample1802) are consistent up to a level of at least: 3.1e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample2007_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample2007_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample2007_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample2007_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample2007_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample2007_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample2007_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample2007_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample2007_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample2007_x=0.0-6-0.05.txt
# Radii (NIsample2007) are consistent up to a level of at least: 4.2e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample2125_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample2125_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample2125_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample2125_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample2125_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample2125_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample2125_x=0.0-6-0.05.txt
# Warning: x_crit adjusted to 5.721999999999907, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample2125_x=0.0-6.6000000000000005-0.05.txt
# Warning: x_crit adjusted to 6.299, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample2125_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample2125_x=0.0-6-0.05.txt
# Radii (NIsample2125) are consistent up to a level of at least: 4.0e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample2245_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample2245_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample2245_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample2245_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample2245_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample2245_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample2245_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample2245_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample2245_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample2245_x=0.0-6-0.05.txt
# Radii (NIsample2245) are consistent up to a level of at least: 4.1e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample2411_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample2411_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample2411_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample2411_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample2411_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample2411_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample2411_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample2411_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample2411_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample2411_x=0.0-6-0.05.txt
# Radii (NIsample2411) are consistent up to a level of at least: 4.3e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample2460_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample2460_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample2460_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample2460_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample2460_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample2460_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample2460_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample2460_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample2460_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample2460_x=0.0-6-0.05.txt
# Warning: Some radii (NIsample2460) are inconsistent at a level of: 2.4e-03
# rn2  (ref,calc): 7.638914963518 7.6253880853097815
# rp2  (ref,calc): 7.581673435522 7.563271099032426
# rch2 (ref,calc): 8.199976134530727 8.185171316555827
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3098_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3098_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3098_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3098_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3098_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3098_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3098_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3098_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3098_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3098_x=0.0-6-0.05.txt
# Radii (NIsample3098) are consistent up to a level of at least: 3.9e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3105_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3105_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3105_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3105_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3105_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3105_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3105_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3105_x=0.0-6.6000000000000005-0.05.txt
# Warning: x_crit adjusted to 6.299, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3105_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3105_x=0.0-6-0.05.txt
# Radii (NIsample3105) are consistent up to a level of at least: 1.0e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3260_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3260_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3260_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3260_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3260_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3260_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3260_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3260_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3260_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3260_x=0.0-6-0.05.txt
# Radii (NIsample3260) are consistent up to a level of at least: 1.6e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3319_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3319_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3319_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3319_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3319_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3319_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3319_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3319_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3319_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3319_x=0.0-6-0.05.txt
# Radii (NIsample3319) are consistent up to a level of at least: 2.6e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3350_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3350_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3350_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3350_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3350_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3350_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3350_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3350_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3350_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3350_x=0.0-6-0.05.txt
# Radii (NIsample3350) are consistent up to a level of at least: 6.7e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3448_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3448_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3448_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3448_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3448_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3448_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3448_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3448_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3448_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3448_x=0.0-6-0.05.txt
# Radii (NIsample3448) are consistent up to a level of at least: 3.7e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3472_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3472_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3472_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3472_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3472_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3472_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3472_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3472_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3472_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3472_x=0.0-6-0.05.txt
# Radii (NIsample3472) are consistent up to a level of at least: 2.8e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3480_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3480_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3480_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3480_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3480_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3480_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3480_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3480_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3480_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3480_x=0.0-6-0.05.txt
# Radii (NIsample3480) are consistent up to a level of at least: 4.9e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3621_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3621_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3621_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3621_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3621_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3621_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3621_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3621_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3621_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3621_x=0.0-6-0.05.txt
# Radii (NIsample3621) are consistent up to a level of at least: 5.6e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample3895_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample3895_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample3895_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample3895_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample3895_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample3895_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample3895_x=0.0-6-0.05.txt
# Warning: x_crit adjusted to 5.747999999999916, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample3895_x=0.0-6.6000000000000005-0.05.txt
# Warning: x_crit adjusted to 6.299, s.t. high-energy continuation is possible
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample3895_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample3895_x=0.0-6-0.05.txt
# Radii (NIsample3895) are consistent up to a level of at least: 1.7e-04
# data loaded from  ./tmp/nucleus_splines/charge_density_M0p_Al27_ab_initio_NIsample4117_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0p_Al27_ab_initio_NIsample4117_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_M0n_Al27_ab_initio_NIsample4117_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_M0n_Al27_ab_initio_NIsample4117_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0p_Al27_ab_initio_NIsample4117_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0p_Al27_ab_initio_NIsample4117_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_Phipp0n_Al27_ab_initio_NIsample4117_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/charge_density_laplace_Phipp0n_Al27_ab_initio_NIsample4117_x=0.0-6.6000000000000005-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_field_Al27_ab_initio_NIsample4117_x=0.0-6-0.05.txt
# data loaded from  ./tmp/nucleus_splines/electric_potential_Al27_ab_initio_NIsample4117_x=0.0-6-0.05.txt
# Radii (NIsample4117) are consistent up to a level of at least: 8.9e-04

# %%
# You may check for good behaviour of the distributions for large r and at the cutoff r_cut 
# You should choose the cutoff r_cut as large as possible while still reproducing the correct radii and not introducting any unphysical oscillations or behaviour in the high energy 
# If radii are consistent or inconsistent is listed as part of the prints above while the other thing can be checked from the plots

# %%
r=np.arange(0,8+0.1,0.1)
for key in AI_dict_27Al:
    key_nucleus = AI_dict_27Al[key]['atom']
    plt.plot(r,key_nucleus.charge_density(r))
plt.title('Charge distributions for $^{27}$Al from IMSRG')
plt.xlabel(r'$r$ in fm')
plt.ylabel(r'$\rho_{\operatorname{ch}}$ in fm$^{-3}$')
plt.grid()
plt.yscale('log')
plt.xlim(0,8)
plt.show()

# %%
# You may try to increase r_cut above and see how the high energy behaviour and warnings about radii consistentcy change (you should soon run into problems)

# %% [markdown]
# # Collect/Calculate basic quantities for correlation (radii, radii squared)

# %%
# The basic function collects/calculates only radii and radii squared, if there are other quantities on file it will also load them

# %%
AI_datasets_27Al = phr.dirac_solvers.post_processing.correlation.calculate_correlation_quantities(AI_dict_27Al)
# Out:
# Loaded (existing) correlation quantities for 1p82p0EM7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0EM7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt
# Loaded (existing) correlation quantities for 1p82p0sim7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0sim7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt
# Loaded (existing) correlation quantities for DN2LOGO from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  DN2LOGO
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt
# Loaded (existing) correlation quantities for EM1p82p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM1p82p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt
# Loaded (existing) correlation quantities for EM2p02p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt
# Loaded (existing) correlation quantities for EM2p02p0PWA from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0PWA
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt
# Loaded (existing) correlation quantities for EM2p22p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p22p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt
# Loaded (existing) correlation quantities for N2LOsat from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  N2LOsat
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt
# Loaded (existing) correlation quantities for NIsample0090 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0090
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt
# Loaded (existing) correlation quantities for NIsample0500 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0500
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt
# Loaded (existing) correlation quantities for NIsample0606 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0606
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt
# Loaded (existing) correlation quantities for NIsample0723 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0723
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt
# Loaded (existing) correlation quantities for NIsample0750 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0750
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt
# Loaded (existing) correlation quantities for NIsample0922 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0922
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt
# Loaded (existing) correlation quantities for NIsample1141 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1141
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt
# Loaded (existing) correlation quantities for NIsample1172 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1172
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt
# Loaded (existing) correlation quantities for NIsample1173 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1173
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt
# Loaded (existing) correlation quantities for NIsample1177 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1177
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt
# Loaded (existing) correlation quantities for NIsample1469 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1469
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt
# Loaded (existing) correlation quantities for NIsample1802 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1802
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt
# Loaded (existing) correlation quantities for NIsample2007 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2007
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt
# Loaded (existing) correlation quantities for NIsample2125 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2125
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt
# Loaded (existing) correlation quantities for NIsample2245 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2245
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt
# Loaded (existing) correlation quantities for NIsample2411 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2411
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt
# Loaded (existing) correlation quantities for NIsample2460 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2460
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt
# Loaded (existing) correlation quantities for NIsample3098 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3098
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt
# Loaded (existing) correlation quantities for NIsample3105 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3105
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt
# Loaded (existing) correlation quantities for NIsample3260 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3260
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt
# Loaded (existing) correlation quantities for NIsample3319 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3319
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt
# Loaded (existing) correlation quantities for NIsample3350 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3350
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt
# Loaded (existing) correlation quantities for NIsample3448 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3448
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt
# Loaded (existing) correlation quantities for NIsample3472 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3472
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt
# Loaded (existing) correlation quantities for NIsample3480 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3480
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt
# Loaded (existing) correlation quantities for NIsample3621 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3621
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt
# Loaded (existing) correlation quantities for NIsample3895 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3895
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt
# Loaded (existing) correlation quantities for NIsample4117 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample4117
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt

# %% [markdown]
# # Correlation Radii

# %%
# This is how you can fairly quickly and easily plot a correlation for quantities that are part of the datasets, using the example of radii squared

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='rchsq',y_strs=['rpsq','rnsq','rwsq'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al,x_ref_label=r'$\langle r^2 \rangle^{\operatorname{ref}}_{\operatorname{ch}}$',y_str_label_trans=lambda x: r'$\langle r^2 \rangle_\operatorname{'+x[1]+'}$')
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))
ax.set_ylabel(r'$\langle r^2 \rangle$ in fm$^{2}$')
ax.set_xlabel(r'$\langle r^2 \rangle_{\operatorname{ch}}$ in fm$^{2}$')
plt.tight_layout()
plt.show()

# %%
# This is how you then calculate the implied values, propagating all uncertainties (the first parameters here are the same as for the plot)

# %%
corr_dict_r2 = phr.dirac_solvers.post_processing.correlation.implications_of_correlation(AI_datasets_27Al,x_str='rchsq',y_strs=['rpsq','rnsq','rwsq'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al)
# Out:
# rpsq=8.76(19)(0)
# rnsq=8.89(20)(6)
# rwsq=9.53(20)(6)

# %%
# This is a special function for convenience for radii because we are usually interested in radii and not radii squared

# %%
corr_dict_sqrsq = phr.dirac_solvers.post_processing.correlation.rsq_dict_add_r_vals(corr_dict_r2)
# Out:
# rch=3.063(31)(0)
# rp=2.961(32)(0)
# rn=2.981(33)(9)
# rw=3.087(32)(10)

# %%
# Just as an example, we may also correlate radii instead of radii squared

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='rch',y_strs=['rp','rn','rw'],x_ref=r_ch_ref_27Al,dx_ref=dr_ch_ref_27Al,x_ref_label=r'$\sqrt{\langle r^2 \rangle^{\operatorname{ref}}_{\operatorname{ch}}}$',y_str_label_trans=lambda x: r'$\sqrt{\langle r^2 \rangle_\operatorname{'+x[1]+'}}$')
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))
ax.set_ylabel(r'$\sqrt{\langle r^2 \rangle}$ in fm$^{2}$')
ax.set_xlabel(r'$\sqrt{\langle r^2 \rangle_{\operatorname{ch}}}$ in fm$^{2}$')
plt.tight_layout()
plt.show()

# %%
# We find the results are very consistent

# %%
corr_dict_r = phr.dirac_solvers.post_processing.correlation.implications_of_correlation(AI_datasets_27Al,x_str='rch',y_strs=['rp','rn','rw'],x_ref=r_ch_ref_27Al,dx_ref=dr_ch_ref_27Al)
# Out:
# rp=2.961(32)(0)
# rn=2.981(34)(10)
# rw=3.087(32)(10)

# %% [markdown]
# # Correlation for custom quantities

# %%
# You may add the calculation of any quantity to the calculate_correlation_quantities call by adding it via the quantities_fct_dict

# %%
# As an example we want to add the r^4 moments of the densities

# %%
from scipy.integrate import quad
def r4_ch_moment_example_function(individual_nucleus):
    norm = individual_nucleus.total_charge
    r4 = 4*pi/norm * quad(lambda x: x**2*x**4*individual_nucleus.charge_density(x), 0 , np.inf ,limit=1000)[0]
    return r4
def r4_p_moment_example_function(individual_nucleus):
    norm = individual_nucleus.Z
    r4 = 4*pi/norm * quad(lambda x: x**2*x**4*individual_nucleus.proton_density(x), 0 , np.inf ,limit=1000)[0]
    return r4
def r4_n_moment_example_function(individual_nucleus):
    norm = individual_nucleus.A - individual_nucleus.Z
    r4 = 4*pi/norm * quad(lambda x: x**2*x**4*individual_nucleus.neutron_density(x), 0 , np.inf ,limit=1000)[0]
    return r4
def r4_w_moment_example_function(individual_nucleus):
    norm = individual_nucleus.weak_charge
    r4 = 4*pi/norm * quad(lambda x: x**2*x**4*individual_nucleus.weak_density(x), 0 , np.inf ,limit=1000)[0]
    return r4

# collect all functions in the dictionary, the keys are the names used to identify the quantities (in case you have other parameters/inputs you want them represented in the key)
r4_moments_fct_dict={'r4ch':r4_ch_moment_example_function,'r4p':r4_p_moment_example_function,'r4n':r4_n_moment_example_function,'r4w':r4_w_moment_example_function}

# %%
# By adding this dictionary to the call these functions are also all evalualted for all sample nuclei

# %%
AI_datasets_27Al = phr.dirac_solvers.post_processing.correlation.calculate_correlation_quantities(AI_dict_27Al,quantities_fct_dict=r4_moments_fct_dict)
# Out:
# Loaded (existing) correlation quantities for 1p82p0EM7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0EM7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt
# Loaded (existing) correlation quantities for 1p82p0sim7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0sim7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt
# Loaded (existing) correlation quantities for DN2LOGO from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  DN2LOGO
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt
# Loaded (existing) correlation quantities for EM1p82p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM1p82p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt
# Loaded (existing) correlation quantities for EM2p02p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt
# Loaded (existing) correlation quantities for EM2p02p0PWA from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0PWA
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt
# Loaded (existing) correlation quantities for EM2p22p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p22p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt
# Loaded (existing) correlation quantities for N2LOsat from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  N2LOsat
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt
# Loaded (existing) correlation quantities for NIsample0090 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0090
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt
# Loaded (existing) correlation quantities for NIsample0500 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0500
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt
# Loaded (existing) correlation quantities for NIsample0606 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0606
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt
# Loaded (existing) correlation quantities for NIsample0723 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0723
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt
# Loaded (existing) correlation quantities for NIsample0750 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0750
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt
# Loaded (existing) correlation quantities for NIsample0922 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0922
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt
# Loaded (existing) correlation quantities for NIsample1141 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1141
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt
# Loaded (existing) correlation quantities for NIsample1172 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1172
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt
# Loaded (existing) correlation quantities for NIsample1173 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1173
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt
# Loaded (existing) correlation quantities for NIsample1177 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1177
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt
# Loaded (existing) correlation quantities for NIsample1469 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1469
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt
# Loaded (existing) correlation quantities for NIsample1802 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1802
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt
# Loaded (existing) correlation quantities for NIsample2007 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2007
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt
# Loaded (existing) correlation quantities for NIsample2125 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2125
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt
# Loaded (existing) correlation quantities for NIsample2245 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2245
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt
# Loaded (existing) correlation quantities for NIsample2411 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2411
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt
# Loaded (existing) correlation quantities for NIsample2460 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2460
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt
# Loaded (existing) correlation quantities for NIsample3098 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3098
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt
# Loaded (existing) correlation quantities for NIsample3105 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3105
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt
# Loaded (existing) correlation quantities for NIsample3260 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3260
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt
# Loaded (existing) correlation quantities for NIsample3319 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3319
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt
# Loaded (existing) correlation quantities for NIsample3350 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3350
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt
# Loaded (existing) correlation quantities for NIsample3448 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3448
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt
# Loaded (existing) correlation quantities for NIsample3472 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3472
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt
# Loaded (existing) correlation quantities for NIsample3480 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3480
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt
# Loaded (existing) correlation quantities for NIsample3621 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3621
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt
# Loaded (existing) correlation quantities for NIsample3895 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3895
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt
# Loaded (existing) correlation quantities for NIsample4117 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample4117
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt

# %%
# And can be accessed now by the keys of the dictionary

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='rchsq',y_strs=['r4ch','r4p','r4n','r4w'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al,x_ref_label=r'$\langle r^2 \rangle^{\operatorname{ref}}_{\operatorname{ch}}$',y_str_label_trans=lambda x: r'$\langle r^4 \rangle_{'+x[2:]+'}$')
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))
ax.set_ylabel(r'$\langle r^4 \rangle$ in fm$^{4}$')
ax.set_xlabel(r'$\langle r^2 \rangle_{\operatorname{ch}}$ in fm$^{2}$')
plt.tight_layout()
plt.show()

# %%
# We again observe a correlation, which however is a bit weaker than for the radii. The plot shows that the microscopic constraintes from the chiral Hamiltonians seem to change r^2 moments and r^4 moments in a correlated way.

# %%
# We may also predict expected values for the r^4 moments based on this correlation

# %%
corr_dict_r = phr.dirac_solvers.post_processing.correlation.implications_of_correlation(AI_datasets_27Al,x_str='rchsq',y_strs=['r4ch','r4p','r4n','r4w'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al)
# Out:
# r4ch=129.5(51)(24)
# r4p=110.8(45)(9)
# r4n=114.7(49)(20)
# r4w=132.7(51)(44)

# %%
# We may calulate the r4 moment also for the reference nucleus and compare to our correlation result for the r^4 moment from the charge distribution
r4_ch_ref = r4_ch_moment_example_function(nuc_ref_27Al) 
r4_ch_ref
# Out:
# np.float64(134.61777795837497)

# %%
# Which is consistent within uncertainty (even without taking the error on r^4 from the reference nucleus into account, which we did not calculate here)

# %% [markdown]
# # Correlation for implemented Quantities

# %%
# For some (more or less common) quantities we have implemented functions to simplify the process of calculating these for all samples

# %% [markdown]
# ## Leading Overlap Integrals in $\mu \to e$ conversion

# %%
# Correlation with fixed charge distribution for the solutions of the muon and electron wave functions

# %%
AI_datasets_27Al = phr.dirac_solvers.post_processing.correlation.calculate_correlation_SI_overlap_integrals(AI_datasets_27Al,reference_nucleus=nuc_ref_27Al)
# Out:
# Loaded (existing) correlation quantities for 1p82p0EM7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0EM7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt
# Loaded (existing) correlation quantities for 1p82p0sim7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0sim7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt
# Loaded (existing) correlation quantities for DN2LOGO from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  DN2LOGO
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt
# Loaded (existing) correlation quantities for EM1p82p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM1p82p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt
# Loaded (existing) correlation quantities for EM2p02p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt
# Loaded (existing) correlation quantities for EM2p02p0PWA from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0PWA
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt
# Loaded (existing) correlation quantities for EM2p22p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p22p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt
# Loaded (existing) correlation quantities for N2LOsat from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  N2LOsat
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt
# Loaded (existing) correlation quantities for NIsample0090 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0090
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt
# Loaded (existing) correlation quantities for NIsample0500 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0500
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt
# Loaded (existing) correlation quantities for NIsample0606 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0606
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt
# Loaded (existing) correlation quantities for NIsample0723 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0723
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt
# Loaded (existing) correlation quantities for NIsample0750 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0750
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt
# Loaded (existing) correlation quantities for NIsample0922 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0922
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt
# Loaded (existing) correlation quantities for NIsample1141 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1141
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt
# Loaded (existing) correlation quantities for NIsample1172 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1172
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt
# Loaded (existing) correlation quantities for NIsample1173 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1173
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt
# Loaded (existing) correlation quantities for NIsample1177 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1177
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt
# Loaded (existing) correlation quantities for NIsample1469 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1469
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt
# Loaded (existing) correlation quantities for NIsample1802 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1802
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt
# Loaded (existing) correlation quantities for NIsample2007 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2007
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt
# Loaded (existing) correlation quantities for NIsample2125 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2125
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt
# Loaded (existing) correlation quantities for NIsample2245 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2245
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt
# Loaded (existing) correlation quantities for NIsample2411 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2411
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt
# Loaded (existing) correlation quantities for NIsample2460 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2460
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt
# Loaded (existing) correlation quantities for NIsample3098 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3098
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt
# Loaded (existing) correlation quantities for NIsample3105 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3105
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt
# Loaded (existing) correlation quantities for NIsample3260 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3260
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt
# Loaded (existing) correlation quantities for NIsample3319 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3319
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt
# Loaded (existing) correlation quantities for NIsample3350 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3350
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt
# Loaded (existing) correlation quantities for NIsample3448 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3448
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt
# Loaded (existing) correlation quantities for NIsample3472 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3472
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt
# Loaded (existing) correlation quantities for NIsample3480 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3480
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt
# Loaded (existing) correlation quantities for NIsample3621 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3621
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt
# Loaded (existing) correlation quantities for NIsample3895 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3895
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt
# Loaded (existing) correlation quantities for NIsample4117 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample4117
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='rchsq',y_strs=['Sp_rhoch_Al27_bestfit_example','Sn_rhoch_Al27_bestfit_example','Vp_rhoch_Al27_bestfit_example','Vn_rhoch_Al27_bestfit_example'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al,x_ref_label=r'$\langle r^2 \rangle^{\operatorname{ref}}_{\operatorname{ch}}$',y_str_label_trans=lambda x: r'$'+x[0]+'_'+x[1]+'$')
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))
ax.set_ylabel(r'overlap integral in $m_{\mu}^{5/2}$')
ax.set_xlabel(r'$\langle r^2 \rangle_{\operatorname{ch}}$ in fm$^{2}$')
plt.tight_layout()
plt.show()

# %%
corr_dict_ov1 = phr.dirac_solvers.post_processing.correlation.implications_of_correlation(AI_datasets_27Al,x_str='rchsq',y_strs=['Sp_rhoch_Al27_bestfit_example','Sn_rhoch_Al27_bestfit_example','Vp_rhoch_Al27_bestfit_example','Vn_rhoch_Al27_bestfit_example'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al)
# Out:
# Sp_rhoch_Al27_bestfit_example=0.01579(19)(2)
# Sn_rhoch_Al27_bestfit_example=0.01689(21)(5)
# Vp_rhoch_Al27_bestfit_example=0.01636(19)(2)
# Vn_rhoch_Al27_bestfit_example=0.01751(21)(5)

# %%
# Correlation with the charge distribution constructed from the ab initio calculation also for the solutions of the muon and electron wave functions

# %%
AI_datasets_27Al = phr.dirac_solvers.post_processing.correlation.calculate_correlation_SI_overlap_integrals(AI_datasets_27Al)
# Out:
# Loaded (existing) correlation quantities for 1p82p0EM7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0EM7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt
# Loaded (existing) correlation quantities for 1p82p0sim7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0sim7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt
# Loaded (existing) correlation quantities for DN2LOGO from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  DN2LOGO
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt
# Loaded (existing) correlation quantities for EM1p82p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM1p82p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt
# Loaded (existing) correlation quantities for EM2p02p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt
# Loaded (existing) correlation quantities for EM2p02p0PWA from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0PWA
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt
# Loaded (existing) correlation quantities for EM2p22p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p22p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt
# Loaded (existing) correlation quantities for N2LOsat from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  N2LOsat
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt
# Loaded (existing) correlation quantities for NIsample0090 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0090
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt
# Loaded (existing) correlation quantities for NIsample0500 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0500
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt
# Loaded (existing) correlation quantities for NIsample0606 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0606
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt
# Loaded (existing) correlation quantities for NIsample0723 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0723
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt
# Loaded (existing) correlation quantities for NIsample0750 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0750
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt
# Loaded (existing) correlation quantities for NIsample0922 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0922
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt
# Loaded (existing) correlation quantities for NIsample1141 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1141
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt
# Loaded (existing) correlation quantities for NIsample1172 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1172
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt
# Loaded (existing) correlation quantities for NIsample1173 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1173
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt
# Loaded (existing) correlation quantities for NIsample1177 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1177
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt
# Loaded (existing) correlation quantities for NIsample1469 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1469
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt
# Loaded (existing) correlation quantities for NIsample1802 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1802
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt
# Loaded (existing) correlation quantities for NIsample2007 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2007
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt
# Loaded (existing) correlation quantities for NIsample2125 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2125
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt
# Loaded (existing) correlation quantities for NIsample2245 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2245
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt
# Loaded (existing) correlation quantities for NIsample2411 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2411
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt
# Loaded (existing) correlation quantities for NIsample2460 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2460
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt
# Loaded (existing) correlation quantities for NIsample3098 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3098
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt
# Loaded (existing) correlation quantities for NIsample3105 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3105
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt
# Loaded (existing) correlation quantities for NIsample3260 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3260
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt
# Loaded (existing) correlation quantities for NIsample3319 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3319
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt
# Loaded (existing) correlation quantities for NIsample3350 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3350
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt
# Loaded (existing) correlation quantities for NIsample3448 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3448
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt
# Loaded (existing) correlation quantities for NIsample3472 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3472
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt
# Loaded (existing) correlation quantities for NIsample3480 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3480
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt
# Loaded (existing) correlation quantities for NIsample3621 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3621
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt
# Loaded (existing) correlation quantities for NIsample3895 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3895
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt
# Loaded (existing) correlation quantities for NIsample4117 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample4117
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='rchsq',y_strs=['Sp_rhoch_from_dataset','Sn_rhoch_from_dataset','Vp_rhoch_from_dataset','Vn_rhoch_from_dataset'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al,x_ref_label=r'$\langle r^2 \rangle^{\operatorname{ref}}_{\operatorname{ch}}$',y_str_label_trans=lambda x: r'$'+x[0]+'_'+x[1]+'$')
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))
ax.set_ylabel(r'overlap integral in $m_{\mu}^{5/2}$')
ax.set_xlabel(r'$\langle r^2 \rangle_{\operatorname{ch}}$ in fm$^{2}$')
plt.tight_layout()
plt.show()

# %%
corr_dict_ov1 = phr.dirac_solvers.post_processing.correlation.implications_of_correlation(AI_datasets_27Al,x_str='rchsq',y_strs=['Sp_rhoch_from_dataset','Sn_rhoch_from_dataset','Vp_rhoch_from_dataset','Vn_rhoch_from_dataset'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al)
# Out:
# Sp_rhoch_from_dataset=0.01568(23)(2)
# Sn_rhoch_from_dataset=0.01677(25)(5)
# Vp_rhoch_from_dataset=0.01624(23)(1)
# Vn_rhoch_from_dataset=0.01738(25)(5)

# %% [markdown]
# ## Charge and Weak form factor

# %%
# Correlation for the form factor evaluated at a specific value of momentum transfer

# %%
q_Qweak=0.77802*phr.constants.hc
q_Qweak # MeV
# Out:
# 153.524337290808

# %%
AI_datasets_27Al = phr.dirac_solvers.post_processing.correlation.calculate_correlation_form_factors(AI_datasets_27Al,q_exp=q_Qweak)
# Out:
# Loaded (existing) correlation quantities for 1p82p0EM7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0EM7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt
# Loaded (existing) correlation quantities for 1p82p0sim7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0sim7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt
# Loaded (existing) correlation quantities for DN2LOGO from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  DN2LOGO
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt
# Loaded (existing) correlation quantities for EM1p82p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM1p82p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt
# Loaded (existing) correlation quantities for EM2p02p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt
# Loaded (existing) correlation quantities for EM2p02p0PWA from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0PWA
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt
# Loaded (existing) correlation quantities for EM2p22p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p22p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt
# Loaded (existing) correlation quantities for N2LOsat from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  N2LOsat
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt
# Loaded (existing) correlation quantities for NIsample0090 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0090
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt
# Loaded (existing) correlation quantities for NIsample0500 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0500
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt
# Loaded (existing) correlation quantities for NIsample0606 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0606
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt
# Loaded (existing) correlation quantities for NIsample0723 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0723
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt
# Loaded (existing) correlation quantities for NIsample0750 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0750
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt
# Loaded (existing) correlation quantities for NIsample0922 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0922
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt
# Loaded (existing) correlation quantities for NIsample1141 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1141
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt
# Loaded (existing) correlation quantities for NIsample1172 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1172
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt
# Loaded (existing) correlation quantities for NIsample1173 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1173
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt
# Loaded (existing) correlation quantities for NIsample1177 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1177
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt
# Loaded (existing) correlation quantities for NIsample1469 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1469
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt
# Loaded (existing) correlation quantities for NIsample1802 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1802
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt
# Loaded (existing) correlation quantities for NIsample2007 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2007
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt
# Loaded (existing) correlation quantities for NIsample2125 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2125
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt
# Loaded (existing) correlation quantities for NIsample2245 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2245
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt
# Loaded (existing) correlation quantities for NIsample2411 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2411
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt
# Loaded (existing) correlation quantities for NIsample2460 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2460
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt
# Loaded (existing) correlation quantities for NIsample3098 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3098
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt
# Loaded (existing) correlation quantities for NIsample3105 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3105
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt
# Loaded (existing) correlation quantities for NIsample3260 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3260
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt
# Loaded (existing) correlation quantities for NIsample3319 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3319
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt
# Loaded (existing) correlation quantities for NIsample3350 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3350
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt
# Loaded (existing) correlation quantities for NIsample3448 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3448
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt
# Loaded (existing) correlation quantities for NIsample3472 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3472
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt
# Loaded (existing) correlation quantities for NIsample3480 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3480
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt
# Loaded (existing) correlation quantities for NIsample3621 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3621
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt
# Loaded (existing) correlation quantities for NIsample3895 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3895
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt
# Loaded (existing) correlation quantities for NIsample4117 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample4117
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='Fch_q153.524',y_strs=['Fw_q153.524'],x_ref=nuc_ref_27Al.form_factor(q_Qweak),x_ref_label=r'$F^\operatorname{ref}_\operatorname{ch}(q_\operatorname{exp})$',y_str_label_trans=lambda x: r'$'+x[0]+'_'+x[1]+'$',plot_color_legend=False)
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))
ax.set_ylabel(r'$F_\operatorname{w}(q_\operatorname{exp})$')
ax.set_xlabel(r'$F_\operatorname{ch}(q_\operatorname{exp})$')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Parity Violating Asymmetry in elastic electron scattering

# %%
# Correlation for the parity violating asymmetry / left right asymmetry of elastic electron nucleus scattering

# %%
# Considered kinematics

# %%
E_beam_Qweak = 1157 
angle_Qweak = 7.61 * pi/180

# %%
# One may either pass a fixed energy and angle (as in the example herer) or a fixed energy, and an angle range and according (unnormalized) acceptances. In the second case the result is averaged over the angles and the acceptance with the equation as quoted in the literature (see e.g. sub. material in CREX & PREX)

# %%
AI_datasets_27Al = phr.dirac_solvers.post_processing.correlation.calculate_correlation_left_right_asymmetry(AI_datasets_27Al,E_exp=E_beam_Qweak,theta_exp=angle_Qweak,left_right_asymmetry_args={'save_and_load_phase_shifts': True})
# Out:
# Loaded (existing) correlation quantities for 1p82p0EM7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0EM7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt
# Loaded (existing) correlation quantities for 1p82p0sim7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0sim7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt
# Loaded (existing) correlation quantities for DN2LOGO from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  DN2LOGO
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt
# Loaded (existing) correlation quantities for EM1p82p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM1p82p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt
# Loaded (existing) correlation quantities for EM2p02p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt
# Loaded (existing) correlation quantities for EM2p02p0PWA from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0PWA
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt
# Loaded (existing) correlation quantities for EM2p22p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p22p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt
# Loaded (existing) correlation quantities for N2LOsat from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  N2LOsat
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt
# Loaded (existing) correlation quantities for NIsample0090 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0090
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt
# Loaded (existing) correlation quantities for NIsample0500 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0500
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt
# Loaded (existing) correlation quantities for NIsample0606 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0606
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt
# Loaded (existing) correlation quantities for NIsample0723 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0723
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt
# Loaded (existing) correlation quantities for NIsample0750 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0750
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt
# Loaded (existing) correlation quantities for NIsample0922 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0922
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt
# Loaded (existing) correlation quantities for NIsample1141 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1141
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt
# Loaded (existing) correlation quantities for NIsample1172 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1172
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt
# Loaded (existing) correlation quantities for NIsample1173 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1173
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt
# Loaded (existing) correlation quantities for NIsample1177 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1177
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt
# Loaded (existing) correlation quantities for NIsample1469 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1469
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt
# Loaded (existing) correlation quantities for NIsample1802 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1802
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt
# Loaded (existing) correlation quantities for NIsample2007 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2007
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt
# Loaded (existing) correlation quantities for NIsample2125 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2125
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt
# Loaded (existing) correlation quantities for NIsample2245 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2245
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt
# Loaded (existing) correlation quantities for NIsample2411 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2411
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt
# Loaded (existing) correlation quantities for NIsample2460 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2460
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt
# Loaded (existing) correlation quantities for NIsample3098 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3098
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt
# Loaded (existing) correlation quantities for NIsample3105 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3105
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt
# Loaded (existing) correlation quantities for NIsample3260 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3260
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt
# Loaded (existing) correlation quantities for NIsample3319 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3319
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt
# Loaded (existing) correlation quantities for NIsample3350 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3350
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt
# Loaded (existing) correlation quantities for NIsample3448 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3448
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt
# Loaded (existing) correlation quantities for NIsample3472 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3472
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt
# Loaded (existing) correlation quantities for NIsample3480 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3480
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt
# Loaded (existing) correlation quantities for NIsample3621 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3621
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt
# Loaded (existing) correlation quantities for NIsample3895 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3895
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt
# Loaded (existing) correlation quantities for NIsample4117 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample4117
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt

# %%
AI_datasets_27Al = phr.dirac_solvers.post_processing.correlation.calculate_correlation_left_right_asymmetry(AI_datasets_27Al,reference_nucleus=nuc_ref_27Al,E_exp=E_beam_Qweak,theta_exp=angle_Qweak,left_right_asymmetry_args={'save_and_load_phase_shifts': True})
# Out:
# Loaded (existing) correlation quantities for 1p82p0EM7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0EM7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0EM7p5.txt
# Loaded (existing) correlation quantities for 1p82p0sim7p5 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  1p82p0sim7p5
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_1p82p0sim7p5.txt
# Loaded (existing) correlation quantities for DN2LOGO from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  DN2LOGO
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_DN2LOGO.txt
# Loaded (existing) correlation quantities for EM1p82p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM1p82p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM1p82p0.txt
# Loaded (existing) correlation quantities for EM2p02p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0.txt
# Loaded (existing) correlation quantities for EM2p02p0PWA from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p02p0PWA
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p02p0PWA.txt
# Loaded (existing) correlation quantities for EM2p22p0 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  EM2p22p0
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_EM2p22p0.txt
# Loaded (existing) correlation quantities for N2LOsat from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  N2LOsat
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_N2LOsat.txt
# Loaded (existing) correlation quantities for NIsample0090 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0090
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0090.txt
# Loaded (existing) correlation quantities for NIsample0500 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0500
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0500.txt
# Loaded (existing) correlation quantities for NIsample0606 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0606
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0606.txt
# Loaded (existing) correlation quantities for NIsample0723 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0723
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0723.txt
# Loaded (existing) correlation quantities for NIsample0750 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0750
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0750.txt
# Loaded (existing) correlation quantities for NIsample0922 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample0922
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample0922.txt
# Loaded (existing) correlation quantities for NIsample1141 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1141
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1141.txt
# Loaded (existing) correlation quantities for NIsample1172 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1172
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1172.txt
# Loaded (existing) correlation quantities for NIsample1173 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1173
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1173.txt
# Loaded (existing) correlation quantities for NIsample1177 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1177
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1177.txt
# Loaded (existing) correlation quantities for NIsample1469 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1469
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1469.txt
# Loaded (existing) correlation quantities for NIsample1802 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample1802
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample1802.txt
# Loaded (existing) correlation quantities for NIsample2007 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2007
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2007.txt
# Loaded (existing) correlation quantities for NIsample2125 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2125
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2125.txt
# Loaded (existing) correlation quantities for NIsample2245 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2245
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2245.txt
# Loaded (existing) correlation quantities for NIsample2411 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2411
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2411.txt
# Loaded (existing) correlation quantities for NIsample2460 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample2460
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample2460.txt
# Loaded (existing) correlation quantities for NIsample3098 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3098
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3098.txt
# Loaded (existing) correlation quantities for NIsample3105 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3105
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3105.txt
# Loaded (existing) correlation quantities for NIsample3260 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3260
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3260.txt
# Loaded (existing) correlation quantities for NIsample3319 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3319
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3319.txt
# Loaded (existing) correlation quantities for NIsample3350 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3350
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3350.txt
# Loaded (existing) correlation quantities for NIsample3448 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3448
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3448.txt
# Loaded (existing) correlation quantities for NIsample3472 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3472
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3472.txt
# Loaded (existing) correlation quantities for NIsample3480 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3480
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3480.txt
# Loaded (existing) correlation quantities for NIsample3621 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3621
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3621.txt
# Loaded (existing) correlation quantities for NIsample3895 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample3895
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample3895.txt
# Loaded (existing) correlation quantities for NIsample4117 from  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt :  [np.str_('rch'), np.str_('rchsq'), np.str_('rp'), np.str_('rpsq'), np.str_('rn'), np.str_('rnsq'), np.str_('rw'), np.str_('rwsq'), np.str_('rw-rch'), np.str_('rn-rp'), np.str_('Sp_rhoch_Al27_bestfit_example'), np.str_('Vp_rhoch_Al27_bestfit_example'), np.str_('Sn_rhoch_Al27_bestfit_example'), np.str_('Vn_rhoch_Al27_bestfit_example'), np.str_('Sch_rhoch_Al27_bestfit_example'), np.str_('Vch_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example'), np.str_('APV_E1157.00_theta0.1328_rhoch_from_dataset'), np.str_('Sp_rhoch_from_dataset'), np.str_('Vp_rhoch_from_dataset'), np.str_('Sn_rhoch_from_dataset'), np.str_('Vn_rhoch_from_dataset'), np.str_('Sch_rhoch_from_dataset'), np.str_('Vch_rhoch_from_dataset'), np.str_('Fch_q153.524'), np.str_('Fw_q153.524'), np.str_('r4ch'), np.str_('r4p'), np.str_('r4n'), np.str_('r4w')]
# Calculating (additional) correlation quantities for:  NIsample4117
# Correlation quantities (overlap integrals, radii, etc.) saved in  ./tmp/correlation_quantities/correlation_quantities_Al27_ab_initio_NIsample4117.txt

# %%
# Experimental results from the Qweak collaboration as comparison
APV_exp=2.16*1e-6
dAPV_exp=np.sqrt(0.11**2+0.16**2)*1e-6

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='rchsq',y_strs=['APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example','APV_E1157.00_theta0.1328_rhoch_from_dataset'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al,
                                                               x_ref_label=r'$\langle r^2 \rangle^{\operatorname{ref}}_{\operatorname{ch}}$',y_str_label_trans=lambda x: x[:3]+('2' if x[-12:]=='from_dataset' else '1'))
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))

xmin, xmax = ax.get_xlim()
ax.plot([xmin,xmax],[APV_exp,APV_exp],linestyle='--',color='C4',zorder=-3)
ax.fill_between([xmin,xmax],2*[APV_exp-dAPV_exp],2*[APV_exp+dAPV_exp],alpha=0.25,color='C4',zorder=-4)
ax.annotate(r'$Q_{\operatorname{weak}}$', (xmin+1e-2,APV_exp-1.05*dAPV_exp),horizontalalignment='left', verticalalignment='top',color='C4')

ax.set_ylabel(r'APV')
ax.set_xlabel(r'$\langle r^2 \rangle_{\operatorname{ch}}$ in fm$^{2}$')
plt.tight_layout()
plt.show()

# %%
corr_dict_APV = phr.dirac_solvers.post_processing.correlation.implications_of_correlation(AI_datasets_27Al,x_str='rchsq',y_strs=['APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example','APV_E1157.00_theta0.1328_rhoch_from_dataset'],x_ref=r_ch_sq_ref_27Al,dx_ref=dr_ch_sq_ref_27Al)
# Out:
# APV_E1157.00_theta0.1328_rhoch_Al27_bestfit_example=0.000002036(51)(13)
# APV_E1157.00_theta0.1328_rhoch_from_dataset=0.000002088(0)(12)

# %%
# Reverse Correlation: Deducing the nucleus skin based on the APV measurement

# %%
fig,ax = plt.subplots(figsize=(5,4), dpi=200)
phr.dirac_solvers.post_processing.correlation.plot_correlation(ax,AI_datasets_27Al,x_str='APV_E1157.00_theta0.1328_rhoch_from_dataset',y_strs=['rw-rch','rn-rp'],x_ref=APV_exp,dx_ref=dAPV_exp,
                                                               x_ref_label=r'$Q_{\operatorname{weak}}$',y_str_label_trans=lambda x: x)
ax.annotate(r'$^{27}$Al', (0.97,0.96) ,xycoords='axes fraction' ,fontsize=10 ,horizontalalignment='right', verticalalignment='top',bbox=dict(boxstyle="round",facecolor=(1,1,1,0.75),edgecolor='lightgray'))
ax.set_ylabel(r'skin thickness in fm')
ax.set_xlabel(r'APV')
plt.tight_layout()
plt.show()

# %%
corr_dict_rskin = phr.dirac_solvers.post_processing.correlation.implications_of_correlation(AI_datasets_27Al,x_str='APV_E1157.00_theta0.1328_rhoch_from_dataset',y_strs=['rw-rch','rn-rp'],x_ref=APV_exp,dx_ref=dAPV_exp)
# Out:
# rw-rch=-0.04(15)(0)
# rn-rp=-0.04(14)(0)

# %%
# Very large uncertainty due to the large uncertainty on the experimental measurement
